# %%
"""
This script will visualise shooting statistics from Dallas, US collected from Dallas police department in SQL database.
SQL database will be read into a pandas dataframe and visualized with folium map.
"""
# Out:
# '\nThis script will visualise shooting statistics from Dallas, US collected from Dallas police department in SQL database.\nSQL database will be read into a pandas dataframe and visualized with folium map.\n'

# %%
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
conn = sqlite3.connect('files/dallas-ois.sqlite') # creating a connector to db

# %%
incidents = pd.read_sql('SELECT * FROM incidents', conn)
officers = pd.read_sql('SELECT * FROM officers', conn)
subjects = pd.read_sql('SELECT * FROM subjects', conn) # reading data drom db

# %%
len(incidents), len(officers), len(subjects)
# Out:
# (219, 370, 223)

# %%
incidents.head()
# Out:
#   case_number        date                  location subject_statuses  \
# 0      44523A  2013-02-23     3000 Chihuahua Street          Injured
# 1     121982X  2010-05-03  1300 N. Munger Boulevard          Injured
# 2     605484T  2007-08-12   200 S. Stemmons Freeway            Other
# 3     384832T  2007-05-26           7900 S. Loop 12   Shoot and Miss
# 4     244659R  2006-04-03        6512 South Loop 12          Injured
#
#   subject_weapon                                           subjects  \
# 0        Handgun                                   Curry, James L/M
# 1        Handgun                                Chavez, Gabriel L/M
# 2        Shotgun                                  Salinas, Nick L/M
# 3        Unarmed  Smith, James B/M; Dews, Antonio B/M; Spearman,...
# 4          Hands                                 Watkins, Caleb B/M
#
#    subject_count                                   officers  officer_count  \
# 0              1  Patino, Michael L/M; Fillingim, Brian W/M              2
# 1              1                       Padilla, Gilbert L/M              1
# 2              1                          Poston, Jerry W/M              1
# 3              3                         Mondy, Michael B/M              1
# 4              1                     Armstrong, Michael W/M              1
#
#   grand_jury_disposition attorney_general_forms_url  \
# 0                No Bill                       None
# 1                No Bill                       None
# 2            See Summary                       None
# 3                   None                       None
# 4                No Bill                       None
#
#                                          summary_url  \
# 0  http://dallaspolice.net/reports/OIS/narrative/...
# 1  http://dallaspolice.net/reports/OIS/narrative/...
# 2  http://dallaspolice.net/reports/OIS/narrative/...
# 3  http://dallaspolice.net/reports/OIS/narrative/...
# 4  http://dallaspolice.net/reports/OIS/narrative/...
#
#                                         summary_text  latitude  longitude
# 0  On Saturday, February 23, 2013, at approximate...       NaN        NaN
# 1  On Monday, May 3, 2010, at approximately 8:06 ...       NaN        NaN
# 2  On Sunday, August 12, 2007, at approximately 2...       NaN        NaN
# 3  On Saturday, May 26, 2007, at approximately 1:...       NaN        NaN
# 4  On Monday, April 3, 2006, at approximately 11:...       NaN        NaN

# %%
#reading sql data into pandas dataset
subject_incidents = pd.read_sql('SELECT * FROM subjects JOIN incidents ON subjects.case_number = incidents.case_number', conn)

# %%
len(subject_incidents)
# Out:
# 223

# %%
subject_incidents.head()
# Out:
#   case_number race gender last_name first_name        full_name case_number  \
# 0      44523A    L      M     Curry      James     Curry, James      44523A
# 1     121982X    L      M    Chavez    Gabriel  Chavez, Gabriel     121982X
# 2     605484T    L      M   Salinas       Nick    Salinas, Nick     605484T
# 3     384832T    B      M     Smith      James     Smith, James     384832T
# 4     384832T    B      M      Dews    Antonio    Dews, Antonio     384832T
#
#          date                  location subject_statuses  ...  \
# 0  2013-02-23     3000 Chihuahua Street          Injured  ...
# 1  2010-05-03  1300 N. Munger Boulevard          Injured  ...
# 2  2007-08-12   200 S. Stemmons Freeway            Other  ...
# 3  2007-05-26           7900 S. Loop 12   Shoot and Miss  ...
# 4  2007-05-26           7900 S. Loop 12   Shoot and Miss  ...
#
#                                             subjects subject_count  \
# 0                                   Curry, James L/M             1
# 1                                Chavez, Gabriel L/M             1
# 2                                  Salinas, Nick L/M             1
# 3  Smith, James B/M; Dews, Antonio B/M; Spearman,...             3
# 4  Smith, James B/M; Dews, Antonio B/M; Spearman,...             3
#
#                                     officers officer_count  \
# 0  Patino, Michael L/M; Fillingim, Brian W/M             2
# 1                       Padilla, Gilbert L/M             1
# 2                          Poston, Jerry W/M             1
# 3                         Mondy, Michael B/M             1
# 4                         Mondy, Michael B/M             1
#
#    grand_jury_disposition attorney_general_forms_url  \
# 0                 No Bill                       None
# 1                 No Bill                       None
# 2             See Summary                       None
# 3                    None                       None
# 4                    None                       None
#
#                                          summary_url  \
# 0  http://dallaspolice.net/reports/OIS/narrative/...
# 1  http://dallaspolice.net/reports/OIS/narrative/...
# 2  http://dallaspolice.net/reports/OIS/narrative/...
# 3  http://dallaspolice.net/reports/OIS/narrative/...
# 4  http://dallaspolice.net/reports/OIS/narrative/...
#
#                                         summary_text latitude  longitude
# 0  On Saturday, February 23, 2013, at approximate...      NaN        NaN
# 1  On Monday, May 3, 2010, at approximately 8:06 ...      NaN        NaN
# 2  On Sunday, August 12, 2007, at approximately 2...      NaN        NaN
# 3  On Saturday, May 26, 2007, at approximately 1:...      NaN        NaN
# 4  On Saturday, May 26, 2007, at approximately 1:...      NaN        NaN
#
# [5 rows x 21 columns]

# %%
subject_incidents.dtypes
# Out:
# case_number                    object
# race                           object
# gender                         object
# last_name                      object
# first_name                     object
# full_name                      object
# case_number                    object
# date                           object
# location                       object
# subject_statuses               object
# subject_weapon                 object
# subjects                       object
# subject_count                   int64
# officers                       object
# officer_count                   int64
# grand_jury_disposition         object
# attorney_general_forms_url     object
# summary_url                    object
# summary_text                   object
# latitude                      float64
# longitude                     float64
# dtype: object

# %%
subject_incidents.isna().sum()
# Out:
# case_number                     0
# race                            0
# gender                          0
# last_name                       0
# first_name                     18
# full_name                       0
# case_number                     0
# date                            0
# location                        0
# subject_statuses                0
# subject_weapon                  0
# subjects                        0
# subject_count                   0
# officers                        0
# officer_count                   0
# grand_jury_disposition         88
# attorney_general_forms_url    221
# summary_url                     3
# summary_text                    3
# latitude                        9
# longitude                       9
# dtype: int64

# %%
subject_incidents.groupby('subject_statuses').count()
# Out:
#                       case_number  race  gender  last_name  first_name  \
# subject_statuses
# 1 Deceased 1 Injured            2     2       2          2           2
# 2 Injured                       1     1       1          1           1
# Deceased                       69    69      69         69          67
# Deceased Injured                2     2       2          2           2
# Injured                        60    60      60         60          60
# Other                           2     2       2          2           2
# Shoot and Miss                 87    87      87         87          71
#
#                       full_name  case_number  date  location  subject_weapon  \
# subject_statuses
# 1 Deceased 1 Injured          2            2     2         2               2
# 2 Injured                     1            1     1         1               1
# Deceased                     69           69    69        69              69
# Deceased Injured              2            2     2         2               2
# Injured                      60           60    60        60              60
# Other                         2            2     2         2               2
# Shoot and Miss               87           87    87        87              87
#
#                       subjects  subject_count  officers  officer_count  \
# subject_statuses
# 1 Deceased 1 Injured         2              2         2              2
# 2 Injured                    1              1         1              1
# Deceased                    69             69        69             69
# Deceased Injured             2              2         2              2
# Injured                     60             60        60             60
# Other                        2              2         2              2
# Shoot and Miss              87             87        87             87
#
#                       grand_jury_disposition  attorney_general_forms_url  \
# subject_statuses
# 1 Deceased 1 Injured                       2                           0
# 2 Injured                                  1                           0
# Deceased                                  67                           1
# Deceased Injured                           2                           0
# Injured                                   58                           1
# Other                                      1                           0
# Shoot and Miss                             4                           0
#
#                       summary_url  summary_text  latitude  longitude
# subject_statuses
# 1 Deceased 1 Injured            2             2         2          2
# 2 Injured                       1             1         1          1
# Deceased                       67            67        68         68
# Deceased Injured                2             2         2          2
# Injured                        60            60        57         57
# Other                           2             2         1          1
# Shoot and Miss                 86            86        83         83

# %%
subject_incidents.groupby('race').count()
# Out:
#       case_number  gender  last_name  first_name  full_name  case_number  \
# race
# A               2       2          2           2          2            2
# B             111     111        111         104        111          111
# L              72      72         72          61         72           72
# W              38      38         38          38         38           38
#
#       date  location  subject_statuses  subject_weapon  subjects  \
# race
# A        2         2                 2               2         2
# B      111       111               111             111       111
# L       72        72                72              72        72
# W       38        38                38              38        38
#
#       subject_count  officers  officer_count  grand_jury_disposition  \
# race
# A                 2         2              2                       0
# B               111       111            111                      67
# L                72        72             72                      37
# W                38        38             38                      31
#
#       attorney_general_forms_url  summary_url  summary_text  latitude  \
# race
# A                              0            2             2         2
# B                              0          109           109       106
# L                              2           71            71        68
# W                              0           38            38        38
#
#       longitude
# race
# A             2
# B           106
# L            68
# W            38

# %%
subject_incidents.groupby('gender').count()
# Out:
#         case_number  race  last_name  first_name  full_name  case_number  \
# gender
# F                 8     8          8           7          8            8
# M               215   215        215         198        215          215
#
#         date  location  subject_statuses  subject_weapon  subjects  \
# gender
# F          8         8                 8               8         8
# M        215       215               215             215       215
#
#         subject_count  officers  officer_count  grand_jury_disposition  \
# gender
# F                   8         8              8                       5
# M                 215       215            215                     130
#
#         attorney_general_forms_url  summary_url  summary_text  latitude  \
# gender
# F                                0            8             8         8
# M                                2          212           212       206
#
#         longitude
# gender
# F               8
# M             206

# %%
subject_incidents.plot.scatter(x='longitude', y='latitude')
# Out:
# <AxesSubplot:xlabel='longitude', ylabel='latitude'>

# %%
dataset = subject_incidents[['race', 'subject_statuses', 'latitude', 'longitude']].dropna()

# %%
len(dataset)
# Out:
# 214

# %%
#mapping features to colors
mapping = {'B': '#ca0020', 'W': '#f4a582', 'A': '#92c5de', 'L': '#0571b0'}
dataset['race'] = dataset['race'].apply(lambda x: mapping[x])
dataset.head()
# Out:
#        race subject_statuses  latitude  longitude
# 9   #0571b0         Deceased  32.68642 -96.908674
# 10  #ca0020         Deceased  32.86400 -96.898998
# 11  #f4a582   Shoot and Miss  32.81482 -96.826787
# 12  #ca0020          Injured  32.77540 -96.767489
# 13  #ca0020   Shoot and Miss  32.74417 -96.828470

# %%
mapping = {'Deceased': 1000, 'Injured': 500, 'Shoot and Miss': 250}
dataset['subject_statuses'] = dataset['subject_statuses'].apply(lambda x: mapping.get(x, 100))
dataset.head()
# Out:
#        race  subject_statuses  latitude  longitude
# 9   #0571b0              1000  32.68642 -96.908674
# 10  #ca0020              1000  32.86400 -96.898998
# 11  #f4a582               250  32.81482 -96.826787
# 12  #ca0020               500  32.77540 -96.767489
# 13  #ca0020               250  32.74417 -96.828470

# %%
dataset.plot.scatter(x='longitude', y='latitude', s='subject_statuses', c='race', alpha=.25, title='Dallas shootings')
# Out:
# <AxesSubplot:title={'center':'Dallas shootings'}, xlabel='longitude', ylabel='latitude'>

# %%
# !pip install folium

# %%
import folium

# %%
m = folium.Map(location=[32.8, -96.8])
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3755fe2d89ae5025511fe4362b5330ee {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3755fe2d89ae5025511fe4362b5330ee&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_3755fe2d89ae5025511fe4362b5330ee = L.map(
#                 &quot;map_3755fe2d89ae5025511fe4362b5330ee&quot;,
#                 {
#                     center: [32.8, -96.8],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b210160f7b53bd861cb811d7cda9bab1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3755fe2d89ae5025511fe4362b5330ee);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
for _, row in dataset.iterrows():
    folium.CircleMarker(
    location=[row['latitude'], row['longitude']],
    radius=row['subject_statuses']//100,
    color=row['race'],
    fill=True,
    fill_color=row['race']
).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3755fe2d89ae5025511fe4362b5330ee {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3755fe2d89ae5025511fe4362b5330ee&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_3755fe2d89ae5025511fe4362b5330ee = L.map(
#                 &quot;map_3755fe2d89ae5025511fe4362b5330ee&quot;,
#                 {
#                     center: [32.8, -96.8],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b210160f7b53bd861cb811d7cda9bab1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3755fe2d89ae5025511fe4362b5330ee);
#
#
#             var circle_marker_e77f16d2f9b05d4074a403343ff21fbb = L.circleMarker(
#                 [32.68642, -96.908674],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#0571b0&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#0571b0&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3755fe2d89ae5025511fe4362b5330ee);
#
#
#             var circle_marker_e7e879612d9b31bd38d07d4cfd365e62 = L.circleMarker(
#                 [32.864, -96.898998],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ca0020&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ca0020&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 10, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3755fe2d89ae5025511fe4362b5330ee);
#
#
#             var circle_marker_4344402dcfc29ffadeda9f47a75fc6cf = L.circleMarker(
#                 [32.81482, -96.826787],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#f4a582&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#f4a582&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3755fe2d89ae5025511fe4362b5330ee);
#
#
#             var circle_marker_6040a72e01a70efc86e0472bbf4d14eb = L.circleMarker(
#                 [32.7754, -96.767489],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ca0020&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ca0020&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3755fe2d89ae5025511fe4362b5330ee);
#
#
#             var circle_marker_585098b835635c6810bfa333fbb60755 = L.circleMarker(
#                 [32.74417, -96.82847],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ca0020&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ca0020&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3755fe2d89ae5025511fe4362b5330ee);
#
#
#             var circle_marker_5d04cacc7fbf775111023dd4446b51ba = L.circleMarker(
#                 [32.945, -96.822619],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#0571b0&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#0571b0&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3755fe2d89ae5025511fe4362b5330ee);
#
#
#             var circle_marker_b4183ab8749a5ff9523d7c4d9de0f20f = L.circleMarker(
#                 [33.0073, -96.831946],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#0571b0&quot;, &quot
